# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamima-Azad/Digital-Image-Processing/blob/main/lab7(0812220105101060).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task-01:** Take a 5x6 NumPy array and plot the histogram of the array with proper
# labels (with and without built in histogram function). Show both histograms side by
# side in a subplot with a title. Show input NumPy array into an image.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
array = np.array([
[255, 0, 1, 100, 25, 101],
[10, 200, 70, 80, 120, 150], # fixed formatting issue: '120' '120
[95, 30, 30, 81, 96, 77],
[87, 89, 220, 250, 100, 10],
[18, 7, 221, 21, 8, 15]
])
hist = np.zeros (256)
for i in range (array.shape [0]):
  for j in range (array.shape [1]):
    hist [array[i, j]] += 1
hist2, bins = np.histogram(array, 256, [0, 256])
plt.figure (figsize=(15, 5))
plt.subplot(1, 3, 1) # 1 row, 3 columns, first subplot
plt.plot(hist) # Plot the histogram values
plt.title('Histogram') # Title for the first plot
# Plot the histogram computed using the built-in function in the second subplot
plt.subplot(1, 3, 2) # 1 row, 3 columns, second subplot
plt.plot (hist2) # Plot the histogram values from built-in function
plt.title('Histogram with built-in function') # Title for second plot
# Display the original NumPy array as a grayscale image in the third subplot
plt.subplot(1, 3, 3) # 1 row, 3 columns, third subplot
plt.imshow (array, cmap='gray') # Show array as grayscale image
plt.title('Numpy Image') # Title for the third plot
# Display all the subplots
plt.show ()
# Assuming 'array' and 'hist' are already defined as in your previous code
# Total number of pixels
total_pixels = array.size
# Number of unique intensity values present
unique_values = np.count_nonzero (hist)
# Most frequent pixel value
most_freq_value = np.argmax (hist)
most_freq_count = hist[most_freq_value]
# Least frequent pixel value (excluding zero-count intensities)
nonzero_hist = hist[hist > 0]
least_freq_value = np.where (hist == nonzero_hist.min()) [0] [0]
least_freq_count = hist[least_freq_value]
# Mean intensity
mean_intensity = np.mean (array)
# Median intensity
median_intensity = np.median (array)
# Standard deviation of intensities
std_intensity = np.std(array)
# Print summary
print("Histogram Summary:")
print(f"Total Pixels: {total_pixels}")
print(f"Unique Intensity Values: {unique_values}")
print(f"Most Frequent Pixel Value: {most_freq_value} (Count:{most_freq_count})")
print(f"Least Frequent Pixel Value: {least_freq_value} (Count:{least_freq_count})")
print(f"Mean Intensity: {mean_intensity:.2f}")
print(f"Median Intensity: {median_intensity}")
print (f"Standard Deviation of Intensities: {std_intensity:.2f}")
# Out:
# Histogram Summary:
# Total Pixels: 30
# Unique Intensity Values: 27
# Most Frequent Pixel Value: 10 (Count:2.0)
# Least Frequent Pixel Value: 0 (Count:1.0)
# Mean Intensity: 85.57
# Median Intensity: 80.5
# Standard Deviation of Intensities: 76.04

# %% [markdown]
# **Task-02: **Take a 8-bit grayscale image and plot the histogram of the image with proper labels (with and without built in histogram function). Show both histograms side by side in a subplot with a title.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('/content/drive/MyDrive/storage_2/CSE-3216/lab2/Copy of WhatsApp Image 2025-08-12 at 09.46.47_a4d4ed4b.jpg')
hist=np.zeros(256)
for i in range(array.shape[0]):
  for j in range(array.shape[1]):
    hist[array[i, j]]+=1
hist2,bins=np.histogram(array,256,[0,256])
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
hist = np.zeros(256)
for i in range(img_gray.shape[0]):
  for j in range(img_gray.shape[1]):
    hist[img_gray[i, j]] += 1
hist2, bins = np.histogram(img_gray, 256, [0, 256])
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.bar(range(256),hist)
plt.title('Histogram')
plt.subplot(1, 2, 2)
plt.bar(range(256),hist2)
plt.title('Histogram with built-in function')
plt.show()
total_pixels = img_gray.size
unique_values = np.count_nonzero(hist)
most_freq_value = np.argmax(hist)
most_freq_count = hist[most_freq_value]
nonzero_hist = hist[hist > 0]
least_freq_value = np.where(hist == nonzero_hist.min())[0][0]
least_freq_count = hist[least_freq_value]
mean_intensity = np.mean(img_gray)
median_intensity = np.median(img_gray)
std_intensity = np.std(img_gray)
print("Histogram Summary for Grayscale Image:")
print(f"Total Pixels: {total_pixels}")
print(f"Unique Intensity Values: {unique_values}")
print(f"Most Frequent Pixel Value: {most_freq_value} (Count:{most_freq_count})")
print(f"Least Frequent Pixel Value: {least_freq_value} (Count:{least_freq_count})")
print(f"Mean Intensity: {mean_intensity:.2f}")
print(f"Median Intensity: {median_intensity}")
print(f"Standard Deviation of Intensities: {std_intensity:.2f}")
# Out:
# Histogram Summary for Grayscale Image:
# Total Pixels: 50625
# Unique Intensity Values: 246
# Most Frequent Pixel Value: 155 (Count:580.0)
# Least Frequent Pixel Value: 1 (Count:1.0)
# Mean Intensity: 123.82
# Median Intensity: 129.0
# Standard Deviation of Intensities: 48.22

# %% [markdown]
# **Task-03:** Take an 8-bit grayscale image and plot the histogram equalized image as well as its histogram with proper labels(with and without built in histogram function). Show both histograms side by side in a subplot with a title. Show both equalized image side by side in a subplot with a title.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read and convert to grayscale
img=cv2.imread('/content/drive/MyDrive/storage_2/CSE-3216/lab2/Copy of WhatsApp Image 2025-08-12 at 09.46.47_a4d4ed4b.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Compute histogram
hist = np.zeros(256)
for i in range(img_gray.shape[0]):
    for j in range(img_gray.shape[1]):
        hist[img_gray[i, j]] += 1

# Compute CDF
cdf = np.zeros(256)
cdf[0] = hist[0]
for i in range(1, 256):
    cdf[i] = cdf[i - 1] + hist[i]

cdf = cdf * 255 / cdf[255]

# Equalized image
img_eq = np.zeros(img_gray.shape)
for i in range(img_gray.shape[0]):
    for j in range(img_gray.shape[1]):
        img_eq[i, j] = cdf[img_gray[i, j]]

# Histogram of equalized image
hist1 = np.zeros(256)
for i in range(img_eq.shape[0]):
    for j in range(img_eq.shape[1]):
        pixel = round(img_eq[i, j])
        hist1[pixel] += 1

# Plot
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.imshow(img_gray, cmap='gray')
plt.title('Original Image')

plt.subplot(2, 2, 2)
plt.imshow(img_eq, cmap='gray')  # fixed typo cmp -> cmap
plt.title('Equalized Image')

plt.subplot(2, 2, 3)
plt.bar(range(256), hist)
plt.title('Histogram of Original Image')

plt.subplot(2, 2, 4)
plt.bar(range(256), hist1)
plt.title('Histogram of Equalized Image')
plt.show()

# Histogram summary function
def histogram_summary(hist_array):
    total_pixels = hist_array.sum()
    unique_values = np.count_nonzero(hist_array)
    most_freq_value = np.argmax(hist_array)
    most_freq_count = hist_array[most_freq_value]

    nonzero_hist = hist_array[hist_array > 0]
    least_freq_value = np.where(hist_array == nonzero_hist.min())[0][0]
    least_freq_count = hist_array[least_freq_value]

    mean_intensity = np.average(np.arange(256), weights=hist_array)
    cumulative = np.cumsum(hist_array)
    median_intensity = np.searchsorted(cumulative, total_pixels // 2)

    variance = np.average((np.arange(256) - mean_intensity) ** 2, weights=hist_array)
    std_intensity = np.sqrt(variance)

    print(f"Histogram Summary:")
    print(f"  Total Pixels: {total_pixels}")
    print(f"  Unique Intensity Values: {unique_values}")
    print(f"  Most Frequent Pixel Value: {most_freq_value} (Count: {most_freq_count})")
    print(f"  Least Frequent Pixel Value: {least_freq_value} (Count: {least_freq_count})")
    print(f"  Mean Intensity: {mean_intensity:.2f}")
    print(f"  Median Intensity: {median_intensity}")
    print(f"  Standard Deviation of Intensities: {std_intensity:.2f}")
    print()

# Call summary function for both images
print("Histogram Summary for Original Image:")
histogram_summary(hist)

print("Histogram Summary for Equalized Image:")
histogram_summary(hist1)
# Out:
# Histogram Summary for Original Image:
# Histogram Summary:
#   Total Pixels: 50625.0
#   Unique Intensity Values: 246
#   Most Frequent Pixel Value: 155 (Count: 580.0)
#   Least Frequent Pixel Value: 1 (Count: 1.0)
#   Mean Intensity: 123.82
#   Median Intensity: 129
#   Standard Deviation of Intensities: 48.22
#
# Histogram Summary for Equalized Image:
# Histogram Summary:
#   Total Pixels: 50625.0
#   Unique Intensity Values: 177
#   Most Frequent Pixel Value: 188 (Count: 580.0)
#   Least Frequent Pixel Value: 0 (Count: 90.0)
#   Mean Intensity: 128.30
#   Median Intensity: 129
#   Standard Deviation of Intensities: 73.65

# %% [markdown]
# **Task-04:** Take an 8-bit grayscale image and a reference image.Write a program to match the histogram of the input image to reference image. Show the original, reference, and matchedd images side by side. Plot their histograms side by side and overlay them in a single graph for comparision. Also, calculate and display a summary for each image including total pixels, number of unique intensity values, most and least frequent pixel values, mean median, and standard deviation.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# --- Load Images (update second path properly) ---
img = cv2.imread('/content/drive/MyDrive/storage_2/CSE-3216/lab2/Copy of WhatsApp Image 2025-08-12 at 09.46.47_a4d4ed4b.jpg', cv2.IMREAD_GRAYSCALE)
ref_img = cv2.imread('/content/drive/MyDrive/storage_2/CSE-3216/lab7/reference_img.jpg', cv2.IMREAD_GRAYSCALE)  # ✅ change to your actual reference image filename

# --- Compute Histogram Function ---
def compute_histogram(image):
    hist = np.zeros(256)
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            hist[image[i, j]] += 1
    return hist

# --- Compute Histograms ---
hist_img = compute_histogram(img)
hist_ref = compute_histogram(ref_img)

# --- Compute CDFs ---
cdf_img = np.cumsum(hist_img)
cdf_ref = np.cumsum(hist_ref)

# --- Normalize CDFs ---
cdf_img_norm = (cdf_img - cdf_img.min()) * 255 / (cdf_img.max() - cdf_img.min())
cdf_ref_norm = (cdf_ref - cdf_ref.min()) * 255 / (cdf_ref.max() - cdf_ref.min())

# --- Create Lookup Table ---
lookup_table = np.zeros(256)
for i in range(256):
    diff = np.abs(cdf_img_norm[i] - cdf_ref_norm)
    lookup_table[i] = np.argmin(diff)
lookup_table = lookup_table.astype(np.uint8)

# --- Apply Mapping ---
matched_img = np.zeros_like(img)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        matched_img[i, j] = lookup_table[img[i, j]]

# --- Compute Histogram of Matched Image ---
hist_matched = compute_histogram(matched_img)

# --- Histogram Summary Function ---
def histogram_summary(hist_array, title="Histogram Summary"):
    total_pixels = hist_array.sum()
    unique_values = np.count_nonzero(hist_array)
    most_freq_value = np.argmax(hist_array)
    most_freq_count = hist_array[most_freq_value]
    nonzero_hist = hist_array[hist_array > 0]
    least_freq_value = np.where(hist_array == nonzero_hist.min())[0][0]
    least_freq_count = hist_array[least_freq_value]
    mean_intensity = np.average(np.arange(256), weights=hist_array)
    cumulative = np.cumsum(hist_array)
    median_intensity = np.searchsorted(cumulative, total_pixels // 2)
    variance = np.average((np.arange(256) - mean_intensity) ** 2, weights=hist_array)
    std_intensity = np.sqrt(variance)

    print(f"{title}:")
    print(f"  Total Pixels: {total_pixels}")
    print(f"  Unique Intensity Values: {unique_values}")
    print(f"  Most Frequent Pixel Value: {most_freq_value} (Count: {most_freq_count})")
    print(f"  Least Frequent Pixel Value: {least_freq_value} (Count: {least_freq_count})")
    print(f"  Mean Intensity: {mean_intensity:.2f}")
    print(f"  Median Intensity: {median_intensity}")
    print(f"  Standard Deviation: {std_intensity:.2f}\n")

# --- Print Summaries ---
histogram_summary(hist_img, "Original Image Histogram")
histogram_summary(hist_ref, "Reference Image Histogram")
histogram_summary(hist_matched, "Matched Image Histogram")

# --- Show Images ---
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(ref_img, cmap='gray')
plt.title('Reference Image')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(matched_img, cmap='gray')
plt.title('Histogram Matched Image')
plt.axis('off')
plt.show()

# --- Show Histograms ---
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.bar(range(256), hist_img, color='blue')
plt.title('Original Image Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')

plt.subplot(1, 3, 2)
plt.bar(range(256), hist_ref, color='red')
plt.title('Reference Image Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')

plt.subplot(1, 3, 3)
plt.bar(range(256), hist_matched, color='green')
plt.title('Matched Image Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# Original Image Histogram:
#   Total Pixels: 50625.0
#   Unique Intensity Values: 246
#   Most Frequent Pixel Value: 155 (Count: 580.0)
#   Least Frequent Pixel Value: 1 (Count: 1.0)
#   Mean Intensity: 123.82
#   Median Intensity: 129
#   Standard Deviation: 48.22
#
# Reference Image Histogram:
#   Total Pixels: 65536.0
#   Unique Intensity Values: 256
#   Most Frequent Pixel Value: 14 (Count: 1576.0)
#   Least Frequent Pixel Value: 253 (Count: 1.0)
#   Mean Intensity: 118.70
#   Median Intensity: 144
#   Standard Deviation: 62.40
#
# Matched Image Histogram:
#   Total Pixels: 50625.0
#   Unique Intensity Values: 150
#   Most Frequent Pixel Value: 14 (Count: 1140.0)
#   Least Frequent Pixel Value: 253 (Count: 2.0)
#   Mean Intensity: 119.15
#   Median Intensity: 145
#   Standard Deviation: 62.09
